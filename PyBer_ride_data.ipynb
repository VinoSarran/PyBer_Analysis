# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
##KIND='bar'
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %%
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
##KIND='bar'
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='pie')
plt.show()

# %%
##KIND='bar'
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='scatter')
plt.show()

# %%
##SKILL DRILL 5.1.10

# %%
import statistics
stdev=pyber_ride_df["Avg. Fare ($USD)"].std()
stdev
# Out:
# 11.208367917035753

# %%
pyber_ride_df.plot.bar(y="Avg. Fare ($USD)",x="Month",yerr=stdev,capsize=6,color='skyblue')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
Add error bars.
Add caps to the error bars.
Change the color of the bars to sky blue.
Rotate the labels on the x-axis to horizontal.
Set the y-axis increment to every $5.

# %%
pyber_ride_df.plot.bar(y="Avg. Fare ($USD)",x="Month",yerr=stdev,capsize=6,color='skyblue')
plt.yticks(np.arange(0, 51, step=5.0))
# Out:
# ([<matplotlib.axis.YTick at 0x176dcee3608>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
